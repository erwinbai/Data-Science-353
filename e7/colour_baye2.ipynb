# %%
import sys
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
from skimage.color import lab2rgb

# %%
# representative RGB colours for each label, for nice display
COLOUR_RGB = {
    'red': (255, 0, 0),
    'orange': (255, 114, 0),
    'yellow': (255, 255, 0),
    'green': (0, 230, 0),
    'blue': (0, 0, 255),
    'purple': (187, 0, 187),
    'brown': (117, 60, 0),
    'pink': (255, 187, 187),
    'black': (0, 0, 0),
    'grey': (150, 150, 150),
    'white': (255, 255, 255),
}
name_to_rgb = np.vectorize(COLOUR_RGB.get, otypes=[np.uint8, np.uint8, np.uint8])


def plot_predictions(model, lum=71, resolution=256):
    """
    Create a slice of LAB colour space with given luminance; predict with the model; plot the results.
    """
    wid = resolution(-100, 100, hei)
    aa, bb = np.meshgrid(ag, bg)
    ll = lum * npe7.ones((hei, wid))
    lab_grid = np.stack([ll, aa, bb], axis=2)
    plt.ylabel('B')
    plt.imshow(X_grid.reshape((hei, wid, 3)))

    plt.subplot(1, 2, 2)
    plt.title('Predicted Labels')
    plt.xticks(np.linspace(0, wid, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.yticks(np.linspace(0, hei, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.xlabel('A')
    plt.imshow(pixels)
    hei = resolution
    n_ticks = 5

    # create a hei*wid grid of LAB colour values, with L=lum
    ag = np.linspace(-100, 100, wid)
    bg = np.linspace(-100, 100, hei)
    aa, bb = np.meshgrid(ag, bg)
    ll = lum * np.ones((hei, wid))
    lab_grid = np.stack([ll, aa, bb], axis=2)eshape(1,-1,3)
    convert_to_lab = rgb2lab(X_reshape) #provided website around middle 'skimage.color.rgb2lab'
    reshape_back = convert_to_lab.reshape(-1,3)
    return reshape_back

    # convert to RGB for consistency with original input
    X_grid = lab2rgb(lab_grid)

    # predict and convert predictions to colours so we can see what's happening
    y_grid = model.predict(X_grid.reshape((wid*hei, 3)))
    pixels = np.stack(name_to_rgb(y_grid), axis=1) / 255
    pixels = pixels.reshape((hei, wid, 3))    bg = np.linspace(-100, 100, hei)
    aa, bb = np.meshgrid(ag, bg)
    ll = lum * npe7.ones((hei, wid))
    lab_grid = np.stack([ll, aa, bb], axis=2)    model_lab = make_pipeline(
    FunctionTransformer(convertor),
    GaussianNB()
    )
}
    dfy = data['Label']
    y = dfy.to_numpy() # array with shape (n,) of colour words.
    #print(y)
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, train_size=0.75)

    # TODO: build model_rgb to predict y from X.
    model_rgb = GaussianNB()
    model_rgb.fit(X_train, y_train)
    y_predicted = model_rgb.predict(X_test)

    # TODO: print model_rgb's accuracy score
#     print('Accuracy score for train:')
#     print(model_rgb.score(X_train, y_train))
    print('Accuracy score for validation data of model_rgb:') #X_test(website) is X_valid(lecture)
    print(model_rgb.score(X_test, y_test))

    
    model_lab = make_pipeline(
    FunctionTransformer(convertor,validate=False),
    GaussianNB()
    )
    
    # TODO: build model_lab to predict y from X by converting to LAB colour first.
    model_lab.fit(X_train, y_train)
    y_predicted = model_lab.predict(X_test)
    
    ': (0, 230, 0),
    'blue': (0, 0, 255),
    'purple': (187, 0, 187),
    'brown': (117, 60, 0),
    'pink': (255, 187, 187),
    'black': (0, 0, 0),
    'grey': (150, 150, 150),
    'white': (255, 255, 255),
    model_lab = make_pipeline(
    FunctionTransformer(convertor),
    GaussianNB()
    )
}
name_to_rgb = np.vectorize(COLOUR_RGB.get, otypes=[np.uint8, np.uint8, np.uint8])


    plt.ylabel('B')
    plt.imshow(X_grid.reshape((hei, wid, 3)))

    plt.subplot(1, 2, 2)
    plt.title('Predicted Labels')
    plt.xticks(np.linspace(0, wid, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.yticks(np.linspace(0, hei, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.xlabel('A')
    plt.xticks(np.linspace(0, wid, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.yticks(np.linspace(0, hei, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.xlabel('A')': (0, 230, 0),
    'blue': (0, 0, 255),
    'purple': (187, 0, 187),
    'brown': (117, 60, 0),
    'pink': (255, 187, 187),
    'black': (0, 0, 0),
    'grey': (150, 150, 150),
    'white': (255, 255, 255),
    model_lab = make_pipeline(
    FunctionTransformer(convertor),    model_lab = make_pipelin(-100, 100, hei)
    aa, bb = np.meshgrid(ag, bg)
    ll = lum * npe7.ones((hei, wid))

    # plot input and predictions
    plt.figure(figsize=(10, 5))
    plt.suptitle('Predictions at L=%g' % (lum,))
    plt.subplot(1, 2, 1)
    plt.title('Inputs'))
}
name_to_rgb = np.vectorize(COLOUR_RGB.get, otypes=[np.uint8, np.uint8, np.uint8])


def plot_predictions(model, lum=71, resolution=256):
    """
    Create a slice of LAB colour space with given luminance; predict with the model; plot the results.
    """
    wid = resolution
    hei = resolution
    n_ticks = 5

    # create a hei*wid grid of LAB colour values, with L=lum
    ag = np.linspace(-100, 100, wid)
    bg = np.linspace(-100, 100, hei)
    aa, bb = np.meshgrid(ag, bg)
    ll = lum * npe7.ones((hei, wid))
    lab_grid = np.stack([ll, aa, bb], axis=2)
    plt.ylabel('B')
    plt.imshow(X_grid.reshape((hei, wid, 3)))

    plt.subplot(1, 2, 2)    bg = np.linspace(-100, 100, hei)
    aa, bb = np.meshgrid(ag, bg)
    ll = lum * npe7.ones((hei, wid))
    lab_grid = np.stack([ll, aa, bb], axis=2)
    plt.ylabel('B')
    plt.imshow(X_grid.reshape((hei, wid, 3)))

    plt.subplot(1, 2, 2)
    plt.title('Predicted Labels')
    plt.xticks(np.linspace(0, wid, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.yticks(np.linspace(0, hei, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.xlabel('A')
    plt.xticks(np.linspace(0, wid, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.yticks(np.linspace(0, hei, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.xlabel('A')': (0, 230, 0),
    'blue': (0, 0, 255),
    'purple': (187, 0, 187),
    'brown': (117, 60, 0),# representative RGB colours for each label, for nice display
COLOUR_RGB = {
    'red': (255, 0, 0),
    'orange': (255, 114, 0),
    'yellow': (255, 255, 0),
    'green': (0, 230, 0),
    'blue': (0, 0, 255),
    'purple': (187, 0, 187),
    'brown': (117, 60, 0),
    'pink': (255, 187, 187),
    'black': (0, 0, 0),
    'grey': (150, 150, 150),
    'white': (255, 255, 255),
}
name_to_rgb = np.vectorize(COLOUR_RGB.get, otypes=[np.uint8, np.uint8, np.uint8])


def plot_predictions(model, lum=71, resolution=256):
    """
    Create a slice of LAB colour space with given luminance; predict with the model; plot the results.
    """
    wid = resolution(-100, 100, hei)
    aa, bb = np.meshgrid(ag, bg)
    ll = lum * npe7.ones((hei, wid))
    lab_grid = np.stack([ll, aa, bb], axis=2)
    plt.ylabel('B')
    plt.imshow(X_grid.reshape((hei, wid, 3)))

    plt.subplot(1, 2, 2)
    plt.title('Predicted Labels')
    plt.xticks(np.linspace(0, wid, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.yticks(np.linspace(0, hei, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.xlabel('A')
    plt.imshow(pixels)
    hei = resolution
    n_ticks = 5

    # create a hei*wid grid of LAB colour values, with L=lum
    ag = np.linspace(-100, 100, wid)
    bg = np.linspace(-100, 100, hei)
    aa, bb = np.meshgrid(ag, bg)
    ll = lum * np.ones((hei, wid))
    lab_grid = np.stack([ll, aa, bb], axis=2)eshape(1,-1,3)
    convert_to_lab = rgb2lab(X_reshape) #provided website around middle 'skimage.color.rgb2lab'
    reshape_back = convert_to_lab.reshape(-1,3)
    return reshape_back

    # convert to RGB for consistency with original input
    X_grid = lab2rgb(lab_grid)

    # predict and convert predictions to colours so we can see what's happening
    y_grid = model.predict(X_grid.reshape((wid*hei, 3)))
    pixels = np.stack(name_to_rgb(y_grid), axis=1) / 255
    pixels = pixels.reshape((hei, wid, 3))    bg = np.linspace(-100, 100, hei)
    aa, bb = np.meshgrid(ag, bg)
    ll = lum * npe7.ones((hei, wid))
    lab_grid = np.stack([ll, aa, bb], axis=2)
    plt.ylabel('B')
    plt.imshow(X_grid.reshape((hei, wid, 3)))

    plt.subplot(1, 2, 2)
    plt.title('Predicted Labels')
    plt.xticks(np.linspace(0, wid, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.yticks(np.linspace(0, hei, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.xlabel('A')
    plt.xticks(np.linspace(0, wid, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.yticks(np.linspace(0, hei, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.xlabel('A')': (0, 230, 0),
    'blue': (0, 0, 255),
    'purple': (187, 0, 187),
    'brown': (117, 60, 0),
    'pink': (255, 187, 187),
    'black': (0, 0, 0),
    'grey': (150, 150, 150),
    'white': (255, 255, 255),
    model_lab = make_pipeline(
    FunctionTransformer(convertor),    model_lab = make_pipelin(-100, 100, hei)
    aa, bb = np.meshgrid(ag, bg)
    ll = lum * npe7.ones((hei, wid))

    # plot input and predictions
    plt.figure(figsize=(10, 5))
    plt.suptitle('Predictions at L=%g' % (lum,))
    plt.subplot(1, 2, 1)
    plt.title('Inputs'))
}
name_to_rgb = np.vectorize(COLOUR_RGB.get, otypes=[np.uint8, np.uint8, np.uint8])


def plot_predictions(model, lum=71, resolution=256):
    """
    Create a slice of LAB colour space with given luminance; predict with the model; plot the results.
    """
    wid = resolution
    hei = resolution
    n_ticks = 5

    # create a hei*wid grid of LAB colour values, with L=lum
    ag = np.linspace(-100, 100, wid)
    bg = np.linspace(-100, 100, hei)
    aa, bb = np.meshgrid(ag, bg)
    ll = lum * npe7.ones((hei, wid))
    lab_grid = np.stack([ll, aa, bb], axis=2)
    plt.ylabel('B')
    plt.imshow(X_grid.reshape((hei, wid, 3)))

    plt.subplot(1, 2, 2)    bg = np.linspace(-100, 100, hei)
    aa, bb = np.meshgrid(ag, bg)
    ll = lum * npe7.ones((hei, wid))
    lab_grid = np.stack([ll, aa, bb], axis=2)
    plt.ylabel('B')
    plt.imshow(X_grid.reshape((hei, wid, 3)))

    plt.subplot(1, 2, 2)
    plt.title('Predicted Labels')
    plt.xticks(np.linspace(0, wid, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.yticks(np.linspace(0, hei, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.xlabel('A')
    plt.xticks(np.linspace(0, wid, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.yticks(np.linspace(0, hei, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.xlabel('A')': (0, 230, 0),
    'blue': (0, 0, 255),
    'purple': (187, 0, 187),
    'brown': (117, 60, 0),
    'pink': (255, 187, 187),
    'black': (0, 0, 0),
    'grey': (150, 150, 150),
    'white': (255, 255, 255),
    model_lab = make_pipeline(
    FunctionTransformer(convertor),    model_lab = make_pipelin(-100, 100, hei)
    aa, bb = np.meshgrid(ag, bg)
    ll = lum * npe7.ones((hei, wid))
    plt.title('Predicted Labels')
    plt.xticks(np.linspace(0, wid, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.yticks(np.linspace(0, hei, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.xlabel('A')
    plt.xticks(np.linspace(0, wid, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.yticks(np.linspace(0, hei, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.xlabel('A')': (0, 230, 0),
    'blue': (0, 0, 255),
    'purple': (187, 0, 187),
    'brown': (117, 60, 0),
    'pink': (255, 187, 187),
    'black': (0, 0, 0),
    'grey': (150, 150, 150),
    'white': (255, 255, 255),
    model_lab = make_pipeline(
    FunctionTransformer(convertor),    model_lab = make_pipelin(-100, 100, hei)
    aa, bb = np.meshgrid(ag, bg)
    ll = lum * npe7.ones((hei, wid))
    lab_grid = np.stack([ll, aa, bb], axis=2)
    plt.ylabel('B')
    plt.imshow(X_grid.reshape((hei, wid, 3)))

    plt.subplot(1, 2, 2)
    plt.title('Predicted Labels')
    plt.xticks(np.linspace(0, wid, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.yticks(np.linspace(0, hei, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.xlabel('A')
    plt.imshow(pixels)e(accrucy
    FunctionTransformer(convertor),
    GaussianNB()
    )
    GaussianNB()
    )
}
name_to_rgb = np.vectorize(COLOUR_RGB.get, otypes=[np.uint8, np.uint8, np.uint8])


def plot_predictions(model, lum=71, resolution=256):
    """
    Create a slice of LAB colour space with given luminance; predict with the model; plot the results.
    """
    wid = resolution
    hei = resolution
    # create a hei*wid grid of LAB colour values, with L=lum
    ag = np.linspace(-100, 100, wid)
    bg = np.linspace(-100, 100, hei)
    aa, bb = np.meshgrid(ag, bg)
    ll = lum * np.ones((hei, wid))
    lab_grid = np.stack([ll, aa, bb], axis=2)

    # convert to RGB for consistency with original input
    X_grid = lab2rgb(lab_grid)

    # predict and convert predictions to colours so we can see what's happening
    y_grid = model.predict(X_grid.reshape((wid*hei, 3)))
    pixels = np.stack(name_to_rgb(y_grid), axis=1) / 255
    pixels = pixels.reshape((hei, wid, 3))

    # plot input and predictions
    plt.figure(figsize=(10, 5))
    plt.suptitle('Predictions at L=%g' % (lum,))
    plt.subplot(1, 2, 1)
    plt.title('Inputs')
    plt.xticks(np.linspace(0, wid, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.yticks(np.linspace(0, hei, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.xlabel('A')
    plt.ylabel('B')
    plt.imshow(X_grid.reshape((hei, wid, 3)))
    n_ticks = 5

    # create a hei*wid grid of LAB colour values, with L=lum
    ag = np.linspace(-100, 100, wid)
    bg = np.linspace(-100, 100, hei)
    aa, bb = np.meshgrid(ag, bg)
    ll = lum * npe7.ones((hei, wid))
    lab_grid = np.stack([ll, aa, bb], axis=2)
    plt.ylabel('B')
    plt.imshow(X_grid.reshape((hei, wid, 3)))

    plt.subplot(1, 2, 2)
    plt.title('Predicted Labels')
    plt.xticks(np.linspace(0, wid, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.yticks(np.linspace(0, hei, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.xlabel('A')
    plt.imshow(pixels)
    'pink': (255, 187, 187),
    'black': (0, 0, 0),
    'grey': (150, 150, 150),
    'white': (255, 255, 255),
    model_lab = make_pipeline(
    FunctionTransformer(convertor),    model_lab = make_pipelin(-100, 100, hei)
    aa, bb = np.meshgrid(ag, bg)
    ll = lum * npe7.ones((hei, wid))
    plt.title('Predicted Labels')
    plt.xticks(np.linspace(0, wid, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.yticks(np.linspace(0, hei, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.xlabel('A')
    plt.xticks(np.linspace(0, wid, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.yticks(np.linspace(0, hei, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.xlabel('A')': (0, 230, 0),
    'blue': (0, 0, 255),
    'purple': (187, 0, 187),
    'brown': (117, 60, 0),
    'pink': (255, 187, 187),
    'black': (0, 0, 0),
    'grey': (150, 150, 150),
    'white': (255, 255, 255),
    model_lab = make_pipeline(
    FunctionTransformer(convertor),    model_lab = make_pipelin(-100, 100, hei)
    aa, bb = np.meshgrid(ag, bg)
    ll = lum * npe7.ones((hei, wid))
    lab_grid = np.stack([ll, aa, bb], axis=2)
    plt.ylabel('B')
    plt.imshow(X_grid.reshape((hei, wid, 3)))

    plt.subplot(1, 2, 2)
    plt.title('Predicted Labels')
    plt.xticks(np.linspace(0, wid, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.yticks(np.linspace(0, hei, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.xlabel('A')
    plt.imshow(pixels)e(
    FunctionTransformer(convertor),
    GaussianNB()
    )
    GaussianNB()
    )
}
name_to_rgb = np.vectorize(COLOUR_RGB.get, otypes=[np.uint8, np.uint8, np.uint8])


def plot_predictions(model, lum=71, resolution=256):
    """
    Create a slice of LAB colour space with given luminance; predict with the model; plot the results.
    """
    wid = resolution
    hei = resolution
    # create a hei*wid grid of LAB colour values, with L=lum
    ag = np.linspace(-100, 100, wid)
    bg = np.linspace(-100, 100, hei)
    aa, bb = np.meshgrid(ag, bg)
    ll = lum * np.ones((hei, wid))
    lab_grid = np.stack([ll, aa, bb], axis=2)

    # convert to RGB for consistency with original input
    X_grid = lab2rgb(lab_grid)

    # predict and convert predictions to colours so we can see what's happening
    y_grid = model.predict(X_grid.reshape((wid*hei, 3)))
    pixels = np.stack(name_to_rgb(y_grid), axis=1) / 255
    pixels = pixels.reshape((hei, wid, 3))

    # plot input and predictions
    plt.figure(figsize=(10, 5))
    plt.suptitle('Predictions at L=%g' % (lum,))
    plt.subplot(1, 2, 1)
    plt.title('Inputs')
    plt.xticks(np.linspace(0, wid, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.yticks(np.linspace(0, hei, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.xlabel('A')
    plt.ylabel('B')
    plt.imshow(X_grid.reshape((hei, wid, 3)))
    n_ticks = 5

    # create a hei*wid grid of LAB colour values, with L=lum
    ag = np.linspace(-100, 100, wid)
    bg = np.linspace(-100, 100, hei)
    aa, bb = np.meshgrid(ag, bg)
    ll = lum * npe7.ones((hei, wid))
    lab_grid = np.stack([ll, aa, bb], axis=2)
    plt.ylabel('B')
    plt.imshow(X_grid.reshape((hei, wid, 3)))

    plt.subplot(1, 2, 2)
    plt.title('Predicted Labels')
    plt.xticks(np.linspace(0, wid, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.yticks(np.linspace(0, hei, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.xlabel('A')
    plt.imshow(pixels)

# %%
# df = pd.read_csv('colour-data.csv')
# print(df)

# %%
#I had to reseach how to take out multiple column from a dataframe
#https://stackoverflow.com/questions/11285613/selecting-multiple-columns-in-a-pandas-dataframe
# dfx = df[['R','G','B']]
# print(dfx):convert_to_lab

# %%
#I learned how to convert and understand that why df.values does not work anymore and we need to use df.to_numpy()
#https://stackoverflow.com/questions/13187778/convert-pandas-dataframe-to-numpy-array
# X = dfx.to_numpy()
#print(data)
# X = X/255
# print(X)

# %%
# dfy = df['Label']
# print(dfy)
# y = dfy.to_numpy()
# print(y)

# %%
from sklearn.model_selection import train_test_split
#X_test and y_test is equal to X_valid and y_valid  
# X_train, X_test, y_train, y_test = train_test_split( 
#     X, y, test_size=0.25, train_size=0.75)

# print(X_train)
# print('----------')
# print(X_test)
# print('----------')
# print(y_train)
# print('----------')
# print(y_test)

# %%
    model_lab = make_pipeline(
    FunctionTransformer(convertor),
    GaussianNB()
    )
}
    dfy = data['Label']
    y = dfy.to_numpy() # array with shape (n,) of colour words.
    #print(y)
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, train_size=0.75)

    # TODO: build model_rgb to predict y from X.
    model_rgb = GaussianNB()
    model_rgb.fit(X_train, y_train)
    y_predicted = model_rgb.predict(X_test)

    # TODO: print model_rgb's accuracy score
#     print('Accuracy score for train:')
#     print(model_rgb.score(X_train, y_train))
    print('Accuracy score for validation data of model_rgb:') #X_test(website) is X_valid(lecture)
    print(model_rgb.score(X_test, y_test))

    
    model_lab = make_pipeline(
    FunctionTransformer(convertor,validate=False),
    GaussianNB()
    )
    
    # TODO: build model_lab to predict y from X by converting to LAB colour first.
    model_lab.fit(X_train, y_train)
    y_predicted = model_lab.predict(X_test)
    
    ': (0, 230, 0),
    'blue': (0, 0, 255),
    'purple': (187, 0, 187),
    'brown': (117, 60, 0),
    'pink': (255, 187, 187),
    'black': (0, 0, 0),
    'grey': (150, 150, 150),
    'white': (255, 255, 255),
    model_lab = make_pipeline(
    FunctionTransformer(convertor),
    GaussianNB()
    )
}
name_to_rgb = np.vectorize(COLOUR_RGB.get, otypes=[np.uint8, np.uint8, np.uint8])

from sklearn.naive_bayes import GaussianNBue': (0, 0, 255),
    'purple': (187, 0, 187),
    'brown': (117, 60, 0),
    'pink': (255, 187, 187),
    'black': (0, 0, 0),
    'grey': (150, 150, 150),
    'white': (255, 255, 255),
    model_lab = make_pipeline(
    FunctionTransformer(convertor),
    GaussianNB()
    )
}
# model_rgb = GaussianNB()
# model_rgb.fit(X_train, y_train)
# print(model_rgb.theta_)  # sample means
# print(model_rgb.sigma_)  # sample variances

# y_predicted = model_rgb.predict(X_test) 

# print(model_rgb.score(X_train, y_train))
# print(model_rgb.score(X_test, y_test))
# print(y_predicted)

# %%
from skimage http://localhost:8888/?token=ff45d55a21f6251a6d37a9236e9352ccfc425653e252420d
.color import rgb2lab
def convertor(X):
    X_reshape = X.reshape(1,-1,3)
    convert_to_lab = rgb2lab(X_reshape) #provided website around middle 'skimage.color.rgb2lab'
    reshape_back = convert_to_lab.reshape(-1,3)
    return reshape_back
# A = convertor(X)
# print(A)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import FunctionTransformer
# model_lab = make_pipeline(
#     FunctionTransformer(convertor),    model_lab.fit(X_train, y_train)
#     GaussianNB()   
# )

# %%
def main(infile):
    data = pd.read_csv(infile)
    dfx = data[['R','G','B']]
    #dfx = dfx.to_numpy()
    X = dfx/255 # array with shape (n, 3). Divide by 255 so components are all 0-1.
    #print(X)
    ue': (0, 0, 255),    model_lab = make_pipeline(
    FunctionTransformer(convertor),
    GaussianNB()
    )
}
    dfy = data['Label']
    y = dfy.to_numpy() # array with shape (n,) of colour words.
    #print(y)
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, train_size=0.75)

    # TODO: build model_rgb to predict y from X.
    model_rgb = GaussianNB()
    model_rgb.fit(X_train, y_train)
    y_predicted = model_rgb.predict(X_test)

    # TODO: print model_rgb's accuracy score
#     print('Accuracy score for train:')
#     print(model_rgb.score(X_train, y_train))
    print('Accuracy score for validation data of model_rgb:') #X_test(website) is X_valid(lecture)
    print(model_rgb.score(X_test, y_test))

    
    model_lab = make_pipeline(
    FunctionTransformer(convertor,validate=False),
    GaussianNB()
    )
    
    # TODO: build model_lab to predict y from X by converting to LAB colour first.
    model_lab.fit(X_train, y_train)
    y_predicted = model_lab.predict(X_test)
    
    ': (0, 230, 0),
    'blue': (0, 0, 255),
    'purple': (187, 0, 187),
    'brown': (117, 60, 0),
    'pink': (255, 187, 187),
    'black': (0, 0, 0),
    'grey': (150, 150, 150),
    'white': (255, 255, 255),
    model_lab = make_pipeline(
    FunctionTransformer(convertor),
    GaussianNB()
    )
}
name_to_rgb = np.vectorize(COLOUR_RGB.get, otypes=[np.uint8, np.uint8, np.uint8])


    'purple': (187, 0, 187),
    'brown': (117, 60, 0),
    'pink': (255, 187, 187),
    'black': (0, 0, 0),
    'grey': (150, 150, 150),
    'white': (255, 255, 255),
    model_lab = make_pipeline(
    FunctionTransformer(convertor),
    GaussianNB()
    )
}
    dfy = data['Label']
    y = dfy.to_numpy() # array with shape (n,) of colour words.
    #print(y)
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, train_size=0.75)

    # TODO: build model_rgb to predict y from X.    model_lab = make_pipeline(
    FunctionTransformer(convertor),
    GaussianNB()
    )
}
    dfy = data['Label']
    y = dfy.to_numpy() # array with shape (n,) of colour words.
    #print(y)
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, train_size=0.75)

    # TODO: build model_rgb to predict y from X.
    model_rgb = GaussianNB()
    model_rgb.fit(X_train, y_train)
    y_predicted = model_rgb.predict(X_test)

    # TODO: print model_rgb's accuracy score
#     print('Accuracy score for train:')
#     print(model_rgb.score(X_train, y_train))
    print('Accuracy score for validation data of model_rgb:') #X_test(website) is X_valid(lecture)
    print(model_rgb.score(X_test, y_test))

    
    model_lab = make_pipeline(
    FunctionTransformer(convertor,validate=False),
    GaussianNB()
    )
    
    # TODO: build model_lab to predict y from X by converting to LAB colour first.
    model_lab.fit(X_train, y_train)
    y_predicted = model_lab.predict(X_test)
    
    ': (0, 230, 0),
    'blue': (0, 0, 255),
    'purple': (187, 0, 187),
    'brown': (117, 60, 0),
    'pink': (255, 187, 187),
    'black': (0, 0, 0),
    'grey': (150, 150, 150),
    'white': (255, 255, 255),
    model_lab = make_pipeline(
    FunctionTransformer(convertor),
    GaussianNB()
    )
}
name_to_rgb = np.vectorize(COLOUR_RGB.get, otypes=[np.uint8, np.uint8, np.uint8])


    model_rgb = GaussianNB()
    model_rgb.fit(X_train, y_train)
    y_predicted = model_rgb.predict(X_test)

    # TODO: print model_rgb's accuracy score
#     print('Accuracy score for train:')
#     print(model_rgb.score(X_train, y_train))
    print('Accuracy score for validation data of model_rgb:') #X_test(website) is X_valid(lecture)
    print(model_rgb.score(X_test, y_test))

    
    model_lab = make_pipeline(
    FunctionTransformer(convertor,validate=False),
    GaussianNB()
    )
    
    # TODO: build model_lab to predict y from X by converting to LAB colour first.
    model_lab.fit(X_train, y_train)
    y_predicted = model_lab.predict(X_test)
    
    ': (0, 230, 0),
    'blue': (0, 0, 255),
    'purple': (187, 0, 187),
    'brown': (117, 60, 0),
    'pink': (255, 187, 187),
    'black': (0, 0, 0),
    'grey': (150, 150, 150),
    'white': (255, 255, 255),
    model_lab = make_pipeline(
    FunctionTransformer(convertor),
    GaussianNB()
    )
}
name_to_rgb = np.vectorize(COLOUR_RGB.get, otypes=[np.uint8, np.uint8, np.uint8])


def plot_predictions(model, lum=71, resolution=256):
    """
    Create a slice of LAB colour space with given luminance; predict with the model; plot the results.
    """
    wid = resolution
    hei = resolutionpipeline(
    FunctionTransformer(convertor),    model_lab = make_pipelin(-100, 100, hei)
    aa, bb = np.meshgrid(ag, bg)
    ll = lum * npe7.ones((hei, wid))
    lab_grid = np.stack([ll, aa, bb], axis=2)
    plt.ylabel('B')
    plt.imshow(X_grid.reshape((hei, wid, 3)))

    plt.subplot(1, 2, 2)
    plt.title('Predicted Labels')
    plt.xticks(np.linspace(0, wid, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.yticks(np.linspace(0, hei, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.xlabel('A')
    plt.imshow(pixels)e(
    FunctionTransformer(convertor),
    GaussianNB()
    )
    n_ticks = 5

    # create a hei*wid grid of LAB colour values, with L=lum
    ag = np.linspace(-100, 100, wid)
    bg = np.linspace(-100, 100, hei)
    aa, bb = np.meshgrid(ag, bg)gb = GaussianNB()
    model_rgb.fit(X_train, y_train)
    y_predicted = model_rgb.predict(X_test)

    # TODO: pttp://localhost:8888/?token=ff45d55a21f6251a6d37a9236e9352ccfc425653e252420drint model_rgb's accuracy score
#     print('Accuracy score for train:')
#     print(model_rgb.score(X_train, y_train))
    print('Accuracy score for validation data of model_rgb:') #X_test(website) is X_valid(lecture)
    print(model_rgb.score(X_test, y_test))

    
    model_lab = make_pipeline(
    FunctionTransformer(convertor,validate=False),
    GaussianNB()
    )
    
    # TODO: build model_lab to predict y from X by converting to LAB colour first.
    model_lab.fit(X_train, y_train)
    y_predicted = model_lab.predict(X_test)
    
    ': (0, 230, 0),
    'blue': (0, 0, 255),pipeline(
    FunctionTransformer(convertor),    model_lab = make_pipelin(-100, 100, hei)
    aa, bb = np.meshgrid(ag, bg)
    ll = lum * npe7.ones((hei, wid))
    lab_grid = np.stack([ll, aa, bb], axis=2)
    plt.ylabel('B')
    plt.imshow(X_grid.reshape((hei, wid, 3)))

    plt.subplot(1, 2, 2)
    plt.title('Predicted Labels')
    plt.xticks(np.linspace(0, wid, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.yticks(np.linspace(0, hei, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.xlabel('A')
    plt.imshow(pixels)e(
    FunctionTransformer(convertor),
    GaussianNB()
    )
    # create a hei*wid grid of LAB colour values, with L=lum
    ag = np.linspace(-100, 100, wid)
    bg = np.linspace(-100, 100, hei)
    aa, bb = np.meshgrid(ag, bg)
    ll = lum * np.ones((hei, wid))
    lab_grid = np.stack([ll, aa, bb], axis=2)
ttp://localhost:8888/?token=ff45d55a21f6251a6d37a9236e9352ccfc425653e252420d
    # convert to RGB for consistency with original input
    X_grid = lab2rgb(lab_grid)

    # predict and convert predictions to colours so we can see what's happening
    y_grid = model.predict(X_grid.reshape((wid*hei, 3)))
    pixels = np.stack(name_to_rgb(y_grid), axis=1) / 255
    pixels = pixels.reshape((hei, wid, 3))

    # plot input and predictions
    plt.figure(figsize=(10, 5))
    plt.suptitle('Predictions at L=%g' % (lum,))
    plt.subplot(1, 2, 1)
    plt.title('Inputs')
    plt.xticks(np.linspace(0, wid, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.yticks(np.linspace(0, hei, n_ticks), np.linspace(-100, 100, n_ticks))
    plt.xlabel('A')
    plt.ylabel('B')
    plt.imshow(X_grid.reshape((hei, wid, 3)))
    'purple': (187, 0, 187),
    'brown': (117, 60, 0),
    'pink': (255, 187, 187),
    'black': (0, 0, 0),
    'grey': (150, 150, 150),
    'white': (255, 255, 255),
    model_lab = make_pipeline(
    FunctionTransformer(convertor),
    GaussianNB()
    ll = lum * npe7.ones((hei, wid))
    lab_grid = np.stack([ll, aa, bb], axis=2)
    # TODO: print model_lab's accuracy score
    print('Accuracy score for valida:convert_to_labtion data of model_lab:') #X_test(website) is X_valid(lecture)
    print(model_lab.score(X_test, y_test))


    plot_predictions(model_rgb)
    plt.savefig('predictions_rgb.png')
    #plot_predictions(model_lab)
    #plt.savefig('predictions_lab.png')
     
              
if __name__ == '__main__':
    #main(sys.argv[1])
    main('colour-data.csv')
# Out:
# Accuracy score for validation data of model_rgb:
# 0.521255060728745
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-8482ddd4c8ea> in <module>
#      47 if __name__ == '__main__':
#      48     #main(sys.argv[1])
# ---> 49     main('colour-data.csv')
#
# <ipython-input-11-8482ddd4c8ea> in main(infile)
#      30
#      31     # TODO: build model_lab to predict y from X by converting to LAB colour first.
# ---> 32     model_lab.fit(X_train, y_train)
#      33     y_predicted = model_lab.predict(X_test)
#      34
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     263             This estimator
#     264         """
# --> 265         Xt, fit_params = self._fit(X, y, **fit_params)
#     266         if self._final_estimator is not None:
#     267             self._final_estimator.fit(Xt, y, **fit_params)
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py in _fit(self, X, y, **fit_params)
#     228                 Xt, fitted_transformer = fit_transform_one_cached(
#     229                     cloned_transformer, Xt, y, None,
# --> 230                     **fit_params_steps[name])
#     231                 # Replace the transformer of the step with the fitted
#     232                 # transformer. This is necessary when loading the transformer
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     340
#     341     def __call__(self, *args, **kwargs):
# --> 342         return self.func(*args, **kwargs)
#     343
#     344     def call_and_shelve(self, *args, **kwargs):
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, **fit_params)
#     612 def _fit_transform_one(transformer, X, y, weight, **fit_params):
#     613     if hasattr(transformer, 'fit_transform'):
# --> 614         res = transformer.fit_transform(X, y, **fit_params)
#     615     else:
#     616         res = transformer.fit(X, y, **fit_params).transform(X)
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     465         else:
#     466             # fit method of arity 2 (supervised transformation)
# --> 467             return self.fit(X, y, **fit_params).transform(X)
#     468
#     469
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_function_transformer.py in transform(self, X, y)
#     158                           DeprecationWarning)
#     159
# --> 160         return self._transform(X, y=y, func=self.func, kw_args=self.kw_args)
#     161
#     162     def inverse_transform(self, X, y='deprecated'):
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_function_transformer.py in _transform(self, X, y, func, kw_args)
#     199
#     200         return func(X, *((y,) if pass_y else ()),
# --> 201                     **(kw_args if kw_args else {}))
#
# <ipython-input-9-391de04ab52f> in convertor(X)
#       1 from skimage.color import rgb2lab
#       2 def convertor(X):
# ----> 3     X_reshape = X.reshape(1,-1,3)
#       4     convert_to_lab = rgb2lab(X_reshape) #provided website around middle 'skimage.color.rgb2lab'
#       5     reshape_back = convert_to_lab.reshape(-1,3)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'reshape'
